# %% [markdown]
# # 自製智能中文選字系統  (1)

# %%
import sys
sys.version
# Out:
# '3.7.3 (v3.7.3:ef4ec6ed12, Mar 25 2019, 22:22:05) [MSC v.1916 64 bit (AMD64)]'

# %% [markdown]
# ## 資料前處理

# %% [markdown]
# 確認版本為 python3

# %%
import re

# %%
# \u4E00-\u9FFF 代表常見中文字，搭配Regex去只選取中文
re.findall(pattern='[\u4E00-\u9FFF]', string='“英語”一詞源於遷居英格蘭的日耳曼部落盎格魯（），而“盎格魯”得名於')
# Out:
# ['英',
#  '語',
#  '一',
#  '詞',
#  '源',
#  '於',
#  '遷',
#  '居',
#  '英',
#  '格',
#  '蘭',
#  '的',
#  '日',
#  '耳',
#  '曼',
#  '部',
#  '落',
#  '盎',
#  '格',
#  '魯',
#  '而',
#  '盎',
#  '格',
#  '魯',
#  '得',
#  '名',
#  '於']

# %%
# \u4E00-\u9FFF 代表常見中文字，搭配Regex去只選取中文
re.findall(pattern='[\u4E00-\u9FFF]+', string='“英語”一詞源於遷居英格蘭的日耳曼部落盎格魯（），而“盎格魯”得名於')
# Out:
# ['英語', '一詞源於遷居英格蘭的日耳曼部落盎格魯', '而', '盎格魯', '得名於']

# %%
# 透過finditer可以得到match物件以及其span, 就可以去判斷在哪
string = '“英語”一詞源於遷居英格蘭的日耳曼部落盎格魯（），而“盎格魯”得名於'
for e in re.finditer(pattern='[\u4E00-\u9FFF]', string=string):
    print(e)
    print(e.span())
    print(string[e.span()[0]])
# Out:
# <re.Match object; span=(1, 2), match='英'>
# (1, 2)
# 英
# <re.Match object; span=(2, 3), match='語'>
# (2, 3)
# 語
# <re.Match object; span=(4, 5), match='一'>
# (4, 5)
# 一
# <re.Match object; span=(5, 6), match='詞'>
# (5, 6)
# 詞
# <re.Match object; span=(6, 7), match='源'>
# (6, 7)
# 源
# <re.Match object; span=(7, 8), match='於'>
# (7, 8)
# 於
# <re.Match object; span=(8, 9), match='遷'>
# (8, 9)
# 遷
# <re.Match object; span=(9, 10), match='居'>
# (9, 10)
# 居
# <re.Match object; span=(10, 11), match='英'>
# (10, 11)
# 英
# <re.Match object; span=(11, 12), match='格'>
# (11, 12)
# 格
# <re.Match object; span=(12, 13), match='蘭'>
# (12, 13)
# 蘭
# <re.Match object; span=(13, 14), match='的'>
# (13, 14)
# 的
# <re.Match object; span=(14, 15), match='日'>
# (14, 15)
# 日
# <re.Match object; span=(15, 16), match='耳'>
# (15, 16)
# 耳
# <re.Match object; span=(16, 17), match='曼'>
# (16, 17)
# 曼
# <re.Match object; span=(17, 18), match='部'>
# (17, 18)
# 部
# <re.Match object; span=(18, 19), match='落'>
# (18, 19)
# 落
# <re.Match object; span=(19, 20), match='盎'>
# (19, 20)
# 盎
# <re.Match object; span=(20, 21), match='格'>
# (20, 21)
# 格
# <re.Match object; span=(21, 22), match='魯'>
# (21, 22)
# 魯
# <re.Match object; span=(25, 26), match='而'>
# (25, 26)
# 而
# <re.Match object; span=(27, 28), match='盎'>
# (27, 28)
# 盎
# <re.Match object; span=(28, 29), match='格'>
# (28, 29)
# 格
# <re.Match object; span=(29, 30), match='魯'>
# (29, 30)
# 魯
# <re.Match object; span=(31, 32), match='得'>
# (31, 32)
# 得
# <re.Match object; span=(32, 33), match='名'>
# (32, 33)
# 名
# <re.Match object; span=(33, 34), match='於'>
# (33, 34)
# 於

# %%
# nice!
def prepocess_line(line):
    # 僅僅挑出中文字元，並且斷開不連續的中文字
    # YOUR CODE HERE
    matches = list(re.finditer(pattern='[\u4E00-\u9FFF]', string=line))
    segments = []
    if len(matches) >= 1:
        # 先把開頭補上去
        chars = [line[matches[0].span()[0]]]
    else:
        chars = []
    matches = list(matches)
    for i in range(len(matches)-1):
        # 如果前後的span是連在一起的就接起來, 否則就是隔開
        if matches[i+1].span()[0] - matches[i].span()[1] == 0:
            chars.append(line[matches[i].span()[1]])
        else:
            segments.append(''.join(chars))
            chars = [line[matches[i+1].span()[0]]]
    # 最後一個!
    if chars:
        segments.append(''.join(chars))
    
    # END YOUR CODE
    return segments

# %%
def prepocess_line(line):
    # 僅僅挑出中文字元，並且斷開不連續的中文字
    # YOUR CODE HERE
    chinese_pattern = r'[\u4E00-\u9FFF]+'
    segments = re.findall(chinese_pattern, line, flags=re.UNICODE)
    # END YOUR CODE
    return segments

# %%
prepocess_line('“英語”一詞源於遷居英格蘭的日耳曼部落盎格魯（），而“盎格魯”得名於')  
# 應該為：['英語', '一詞源於遷居英格蘭的日耳曼部落盎格魯', '而', '盎格魯', '得名於']
# Out:
# ['英語', '一詞源於遷居英格蘭的日耳曼部落盎格魯', '而', '盎格魯', '得名於']

# %%
segments = []
with open('./datasets/wiki_zh_small.txt', encoding='utf8') as fr:
    for line in fr.readlines():
        segments += prepocess_line(line)

# %%
segments[:10]
# Out:
# ['英語',
#  '英語英語',
#  '又稱爲英文',
#  '是一種西日耳曼語言',
#  '誕生於中世紀早期的英格蘭',
#  '如今具有全球通用語的地位',
#  '英語',
#  '一詞源於遷居英格蘭的日耳曼部落盎格魯',
#  '而',
#  '盎格魯']

# %%
from collections import Counter

Counter(segments)
# Out:
# Counter({'英語': 8,
#          '英語英語': 1,
#          '又稱爲英文': 1,
#          '是一種西日耳曼語言': 1,
#          '誕生於中世紀早期的英格蘭': 1,
#          '如今具有全球通用語的地位': 1,
#          '一詞源於遷居英格蘭的日耳曼部落盎格魯': 1,
#          '而': 37,
#          '盎格魯': 3,
#          '得名於臨波羅的海的半島盎格里亞': 1,
#          '弗裏西語是與英語最相近的語言': 1,
#          '英語詞彙在中世紀早期受到了其他日耳曼族語言的大量影響': 1,
#          '後來受羅曼族語言尤其是法語的影響': 1,
#          '英語是將近六十個國家唯一的官方語言或官方語言之一': 1,
#          '也是全世界最多國家的官方語言': 1,
#          '它是英國': 1,
#          '愛爾蘭': 2,
#          '美國': 16,
#          '加拿大': 9,
#          '澳大利亞和新西蘭最常用的語言': 1,
#          '也在加勒比': 1,
#          '非洲及南亞的部分地區被廣泛使用': 1,
#          '英語是世界上母語人口第三多的語言': 1,
#          '僅次於漢語和西班牙語': 1,
#          '英語是學習者最多的第一外語': 1,
#          '是聯合國': 1,
#          '歐盟和許多其他國際組織的官方語言': 1,
#          '它是使用最廣泛的日耳曼族語言': 1,
#          '至少': 4,
#          '的日耳曼語族使用者說英語': 1,
#          '英語有': 1,
#          '多年的發展史': 1,
#          '公元': 17,
#          '世紀': 54,
#          '撒克遜人把他們的各種盎格魯': 1,
#          '弗裏西語方言帶到了大不列顛島': 1,
#          '它們被稱爲古英語': 1,
#          '中古英語始於': 1,
#          '世紀後期的諾曼征服': 1,
#          '這一時期英語受到了法語的影響': 1,
#          '世紀初': 12,
#          '倫敦對印刷機的採用': 1,
#          '欽定版聖經': 1,
#          '的出版及元音大推移標誌了近代英語的開端': 1,
#          '通過大英帝國對全球的影響': 1,
#          '現代英語在': 1,
#          '世紀至': 1,
#          '世紀中葉傳播到了世界各地': 1,
#          '通過各種印刷和電子媒體': 1,
#          '隨着美國取得全球超級大國地位': 1,
#          '英語已經成爲了國際對話中居領導地位的世界語言': 1,
#          '它還是許多地區和行業': 1,
#          '如科學': 1,
#          '導航': 1,
#          '法律等': 1,
#          '的通用語': 1,
#          '現代英語和很多其他語言相比屈折變化較少': 1,
#          '更多地依靠助動詞和語序來表達複雜的時態': 1,
#          '體和語氣': 1,
#          '以及被動語態': 1,
#          '疑問和一些否定': 1,
#          '英語的各種口音和方言在發音和音位方面有顯著差異': 1,
#          '有時它們的詞彙': 1,
#          '語法和拼法也有所不同': 1,
#          '但世界各地說英語的人能基本無礙地溝通交流': 1,
#          '早期日耳曼人西支部落': 1,
#          '盎格魯族': 1,
#          '撒克遜族': 2,
#          '朱特族和弗裏西族': 1,
#          '移民到英格蘭': 1,
#          '英語就是從他們的語言中變化繼承下來的': 1,
#          '據': 8,
#          '盎格魯撒克遜編年史': 1,
#          '記載': 8,
#          '年左右': 7,
#          '不列顛羣島國王伏提庚': 1,
#          '邀請': 1,
#          '盎格魯親戚們': 1,
#          '來幫助他對抗皮克特人': 1,
#          '於是他賜予盎格魯族東南部的領土作爲回報': 1,
#          '隨後他又進一步尋求支援': 1,
#          '盎格魯族與朱特族人便紛紛前來': 1,
#          '編年史': 1,
#          '最終這些': 1,
#          '移民': 1,
#          '建立了七個王國': 1,
#          '諾森布里亞': 1,
#          '麥西亞': 1,
#          '東盎格利亞': 2,
#          '肯特': 1,
#          '埃塞克斯': 1,
#          '蘇塞克斯和威塞克斯': 1,
#          '日爾曼人入侵後': 1,
#          '統治了當地的凱爾特語民族': 1,
#          '本地語言主要於蘇格蘭': 1,
#          '威爾士': 1,
#          '這三個詞是分別從描繪盎格魯族的三個詞彙': 1,
#          '發展而來的': 1,
#          '公元九世紀': 1,
#          '斯堪的納維亞的丹麥人大規模侵入英國北部': 1,
#          '九世紀末': 1,
#          '入侵者幾乎佔領了整個英國的東半部': 1,
#          '丹麥人說的是北日爾曼語': 1,
#          '北日爾曼語和西日爾曼語的詞彙上差別不是很懸殊': 1,
#          '爲提升溝通程度常替詞形變化有意無意消音': 1,
#          '古英語曲折變化的融蝕也在此開端': 1,
#          '斯堪的納維亞人入侵使大量斯堪的納維亞語': 1,
#          '以古諾斯語爲代表': 1,
#          '的詞彙融進古英語中': 1,
#          '古諾斯語和古英語有許多同義同源': 1,
#          '型態近似之類語': 1,
#          '古英語在丹麥統治下吸收不少古諾斯語詞彙': 1,
#          '其中最顯著及最具代表性的': 1,
#          '是英語的人稱代名詞': 1,
#          '爲古諾斯語取代原本古英語詞彙': 1,
#          '即北日耳曼語式的代名詞取代英語原本西日耳曼語式代名詞': 1,
#          '而演變至今日樣貌': 1,
#          '年': 1167,
#          '法國的諾曼第公爵征服英格蘭': 1,
#          '在西敏寺登基加冕': 1,
#          '史稱征服者威廉': 1,
#          '諾曼征服後三百年內': 1,
#          '英國君主與貴族講一種屬奧依語的古法語方言盎格魯': 1,
#          '諾曼語': 1,
#          '教士們則習用拉丁文': 1,
#          '古英語淪落爲平民以及農奴的語言': 1,
#          '因重要場合及貴族的使用': 1,
#          '諾曼語強烈影響古英語': 1,
#          '古英語也因當時地位相對下賤': 1,
#          '缺乏對文法規範的重視和約束': 1,
#          '迅速大量丟失早期複雜的曲折變化': 1,
#          '進而發展形成中古英語': 1,
#          '年左右的元音大推移將中古英語變形爲近代英語': 1,
#          '古英語最著名的文學作品是': 1,
#          '貝奧武夫': 1,
#          '中古英語則是': 1,
#          '坎特伯裏故事集': 1,
#          '近代英語在莎士比亞所處的時期開始繁榮': 1,
#          '一些學者將之分爲早期近代英語與後期近代英語': 1,
#          '分界線爲': 1,
#          '隨著不列顛對全世界大部分地區的佔領和殖民': 1,
#          '當地語言也很大程度上影響了英語的發展': 1,
#          '雖然英語是屬於日耳曼語族的語言': 1,
#          '但在文藝復興時期時英語加入了大量拉丁語的詞彙': 1,
#          '隨著時代演進還加入更多西班牙語': 1,
#          '義大利語': 1,
#          '法語及希臘語的詞彙': 1,
#          '英語是一種多中心語言': 1,
#          '由於英語的使用範圍極爲廣泛': 1,
#          '不可避免地出現了各種地區性變體': 1,
#          '語言學家已經不再把倫敦或英國上層人士的英語作爲唯一的標準英語': 1,
#          '除英國英語外': 1,
#          '最重大發展的是美國英語和紐澳英語': 1,
#          '自從': 11,
#          '美國英語': 1,
#          '加拿大英語': 1,
#          '澳洲英語': 1,
#          '紐西蘭英語開始成爲獨特的方言': 1,
#          '它們也各有自己的地區性的語詞': 1,
#          '語法和語音': 1,
#          '其他像印度英語': 1,
#          '東南亞英語': 1,
#          '加勒比地區英語和非洲某些新興國家的英語': 1,
#          '都各自受到了當地語言影響': 1,
#          '具有語音和詞彙上的特點': 1,
#          '英語的主要方言在語音上有著相當明顯的差別': 1,
#          '拼寫的差別則較小': 1,
#          '一般人們以一些學術機構的辭書作爲標準的英語': 1,
#          '例如': 86,
#          '牛津英語詞典': 2,
#          '等': 56,
#          '在學術': 1,
#          '科技文章方面': 1,
#          '來自各國作者使用的是一種共同文體': 1,
#          '第二次世界大戰以前': 1,
#          '美式英語': 1,
#          '這個術語通常被理解爲美國人特有的語詞和語法': 1,
#          '在當時的一些': 1,
#          '純潔主義': 1,
#          '的英國文人看來': 1,
#          '它不是純正的英文': 1,
#          '但到了第二次世界大戰前後': 1,
#          '美國式英語': 1,
#          '一詞的概念逐漸變了': 1,
#          '只指在美國本土上使用的英語': 1,
#          '而不論其與英國式英語的異同': 1,
#          '在第二次世界大戰以後': 1,
#          '由於美國取代英國成爲世界第一強國': 1,
#          '通過大衆傳播媒介迅速發展': 1,
#          '美國式英語已反過來對其他方言產生影響': 1,
#          '並且正在日益擴大這種影響': 1,
#          '電腦軟件也以美國式英語爲標準': 1,
#          '由於大英帝國在世界各地有過許多殖民地': 1,
#          '在現代': 1,
#          '英語在許多國家與地區': 1,
#          '都是通用語言或官方語言之一': 1,
#          '由於使用英語的兩個主要國家': 1,
#          '英國與美國': 1,
#          '先後成爲世界超級大國之故': 1,
#          '並在商業': 1,
#          '學術領域具較大影響力': 1,
#          '在科技方面的突出貢獻和領先地位': 1,
#          '而且英文相當易學': 1,
#          '因此許多人都將英語做爲一種外語或第二語言': 1,
#          '把英語作爲外國語使用的人約': 1,
#          '億': 7,
#          '英語在歐洲大陸及日本是最普遍作爲外語來學習的語言': 1,
#          '接着是法語': 1,
#          '德語和西班牙語': 1,
#          '在中國大陸': 5,
#          '香港和澳門特區': 1,
#          '臺灣': 7,
#          '韓國': 12,
#          '日本等地': 1,
#          '英語是學校的必修外語課程': 1,
#          '英語作爲第二語言和作爲外國語這兩種不同的使用法': 1,
#          '說明英語正在愈來愈被看成一種國際交往的工具': 1,
#          '它不再爲一國或一個民族所專有': 1,
#          '而是一種中性的信息媒介': 1,
#          '基本英語是爲了國際交流使用而簡化了的英語': 1,
#          '它通常被一些飛機廠商和其他國際企業用作書寫手冊和交流': 1,
#          '遠東的一些學校把它作爲基礎英語來教授': 1,
#          '中華人民共和國的基本教育': 1,
#          '小學至高中': 1,
#          '階段': 1,
#          '特別是中學階段': 1,
#          '幾乎全部的學校選擇英語作爲其主要或唯一的外語必修課': 1,
#          '中國大陸自': 1,
#          '年代末期至': 1,
#          '年代初期開始': 1,
#          '在全日制普通大學推行大學英語等級考試': 1,
#          '作爲對選擇英語作爲第一外語必修課課程與拿到大學畢業證書的達標要求': 1,
#          '中華人民共和國從': 1,
#          '年至在': 1,
#          '年代中期': 1,
#          '因與蘇聯的關係極爲密切': 1,
#          '主要以俄語作爲第一外語': 1,
#          '直至文化大革命': 1,
#          '從': 49,
#          '年代中期以後': 1,
#          '逐漸選擇英語作爲第一外語': 1,
#          '年特別是': 1,
#          '年以後': 4,
#          '英語是在高等學校升學考試中': 1,
#          '和其他主要科目一樣同等對待': 1,
#          '以此爲導向': 1,
#          '中國大陸的中學課程': 1,
#          '特別是初中教育絕大多數以英語作爲外語教學課程的必修課': 1,
#          '也因爲這樣': 1,
#          '許多中國大陸人說話時會自動將英語和外語等同': 1,
#          '除了非英語外語專業以外': 1,
#          '在全日制普通大學': 1,
#          '一般均以英語作爲必修課': 1,
#          '其他外語作爲選修': 1,
#          '而非英語專業的語言專業': 1,
#          '一般要求同時對英語作爲必要課程之列': 1,
#          '在臺灣': 4,
#          '英語是所有中小學生的必修外語課程': 1,
#          '大學也往往要求學生的英語程度需達到一定水準': 1,
#          '同時臺灣許多大學的專業課程常常使用英語教科書': 1,
#          '習稱': 1,
#          '原文書': 1,
#          '由於英語是所有臺灣中小學生必修課程': 1,
#          '亦是重要的國際交流語言與中學和大學的應試科目之一的緣故': 1,
#          '因此以坊間爲應試': 1,
#          '會話等目的而出的英語參考書非常多': 1,
#          '也有許多補習班教授': 1,
#          '補強學生英語': 1,
#          '外商公司大多有要求英語作爲應徵門檻': 1,
#          '其中要求英語程度大多爲全民英檢中級以上': 1,
#          '英語音系學是指對英語音系': 1,
#          '亦即聲音系統': 1,
#          '的研究': 1,
#          '正如所有語言': 1,
#          '無論考慮歷史與否': 1,
#          '英語口語的發音因不同方言而異': 1,
#          '這種變異在英語特別明顯': 1,
#          '因爲它在廣泛地區使用': 1,
#          '是英國': 1,
#          '澳洲': 1,
#          '新西蘭和加勒比海英語國家等國的主要語言': 1,
#          '在每一個洲都有人以之爲母語或第二語言': 1,
#          '英語並沒有決定性和國際承認的標準': 1,
#          '所以不同國家的英語有時可能妨礙溝通': 1,
#          '雖然如此': 3,
#          '不同地區的英語口音仍能互相理解': 1,
#          '英語語法基於日耳曼語源': 1,
#          '雖然一些': 1,
#          '世紀和': 3,
#          '世紀的學者試圖把拉丁語的語法應用於英語': 1,
#          '但是並不成功': 1,
#          '英語與其他所有的印歐語系語言相比': 1,
#          '沒有那麼複雜的屈折變化': 1,
#          '也失去了幾乎所有陰陽性變化': 1,
#          '基本上': 2,
#          '英語除了人稱代詞以外': 1,
#          '已失去了性和格的分別了': 1,
#          '它更強調詞語間相對固定的順序': 1,
#          '也就是說英語正朝向分析語的方向發展': 1,
#          '如貓尾可以寫作': 1,
#          '而不必寫作': 1,
#          '這裏的貓': 1,
#          '直接用了詞根原形': 1,
#          '而沒用屬格詞綴': 1,
#          '英語的基本語序爲': 1,
#          '且基本上不能任意變換語序': 1,
#          '除了在少數詩詞以外': 1,
#          '如下所示': 1,
#          '英語中仍然保留的屈折變化有': 1,
#          '比起其他印歐語系的語言': 1,
#          '雖然英語的屈折變化數量大幅減少': 1,
#          '但名詞': 1,
#          '動詞等依舊有相當數量的不規則變化與強變化': 1,
#          '英語中所有的詞可分成十大類': 1,
#          '每一類詞在句子中都有其特定的位置和作用': 1,
#          '這十大詞類是': 1,
#          '幾乎所有的日耳曼語源字彙': 1,
#          '包括一切基本字彙': 1,
#          '如代詞': 1,
#          '連詞等': 1,
#          '都相對來說更短': 1,
#          '更非正式': 1,
#          '拉丁語源的字彙通常代表更加優雅或更能顯示專業造詣': 1,
#          '但是': 22,
#          '過多運用拉丁語源字彙': 1,
#          '則會被認爲矯飾或刻意賣弄': 1,
#          '喬治': 1,
#          '奧威爾的文章': 1,
#          '政治與英語': 1,
#          '對此作了透徹的描寫': 1,
#          '英語使用者在選擇單詞時': 1,
#          '通常可以從日耳曼語源和拉丁語源的近義字彙中挑選': 1,
#          '如': 75,
#          '和': 233,
#          '這些近義詞之間都有微妙的差異': 1,
#          '使用者能夠自由選擇組合表達不同的觀點': 1,
#          '日常生活中': 1,
#          '大部分所用到的辭彙一般是日耳曼語源': 1,
#          '大多數拉丁語源的字彙通常用在更加正式的講話和文章中': 1,
#          '比如法庭發言或者編寫百科全書': 1,
#          '在醫學': 1,
#          '化學等的許多術語也爲拉丁語詞源': 1,
#          '英語以它巨大的詞彙量而著稱': 1,
#          '很容易引入專業術語和輸入新詞到日常使用中': 1,
#          '另外': 45,
#          '俚語也爲舊詞換上了新的含義': 1,
#          '這種靈活性非常明顯': 1,
#          '通常需要正確區分正式的用法和日常一般用法': 1,
#          '英美的初等教育教師一般會提醒學生那些日常廣泛使用但在正式場合中並不正確的字彙': 1,
#          '請參看': 2,
#          '社會語言學': 1,
#          '英語的詞彙量非常龐大': 1,
#          '總計': 1,
#          '個': 80,
#          '但如果要估計具體數字': 1,
#          '必須先判斷哪些能夠算作其單詞': 1,
#          '不過與其他語言不同': 1,
#          '並沒有一個權威學術機構來規定何爲正式的辭彙': 1,
#          '醫學': 2,
#          '科技領域不斷湧現新詞': 1,
#          '一些進入了大衆日常用語中': 1,
#          '其他只在一小部分人羣內部使用': 1,
#          '移民羣體帶來的外語單詞也經常融入英語社會中去': 1,
#          '一些古詞和方言單詞能否算作英語也無法判斷': 1,
#          '第二版': 1,
#          '收錄了超過五十萬個條目': 1,
#          '標準比較寬鬆': 1,
#          '包括文學與日常對話中的標準辭彙': 1,
#          '無論當代': 1,
#          '廢棄或古語': 1,
#          '也包括主要的科技辭彙和大量方言': 1,
#          '俚語': 1,
#          '自從電子計算機普及以來': 1,
#          '不少與這範疇相關的詞語進入大衆的生活': 1,
#          '另一方面': 14,
#          '與電信科技相關的新詞': 1,
#          '有不少都是透過詞綴的組合來構成新詞': 1,
#          '舉個例子': 1,
#          '本身是夏威夷語': 1,
#          '但由於維基百科的普及': 1,
#          '創建了': 2,
#          '維基化的意思': 1,
#          '然後又從': 1,
#          '維基化的過程或行動': 1,
#          '在數據庫中使用的一個新創詞語': 1,
#          '意思是': 4,
#          '把準備寫入數據庫的資料序列化的可行性': 1,
#          '本身亦是源自另一個新創建詞': 1,
#          '序列化': 1,
#          '源自': 2,
#          '即序列': 1,
#          '英語藉詞的詞源很廣泛': 1,
#          '由於曾受到法語的影響': 1,
#          '英語詞彙在一定程度上大致分爲日耳曼詞源': 1,
#          '大部分來自古英語': 1,
#          '與拉丁語源': 1,
#          '由拉丁語而來': 1,
#          '大部分來自諾曼法語': 1,
#          '有一些也直接從拉丁語借來': 1,
#          '與出版': 1,
#          '書中發表報告': 1,
#          '對舊版': 1,
#          '簡明牛津字典': 1,
#          '第三版': 1,
#          '中約八萬個單詞進行了電腦化調查': 1,
#          '報告結果顯示英語單詞來源如下': 1,
#          '英語的書寫使用拉丁字母': 1,
#          '單詞的拼寫系統或正確拼寫法是依據歷史傳統而繼承下來的': 1,
#          '並不嚴格按照發音規律': 1,
#          '因此': 31,
#          '英語單詞的發音與拼寫之間經常有很大差異': 1,
#          '單詞拼法也是所有字母語言中最難掌握的拼寫之一': 1,
#          '世界絕大多數的拼音文字是屬於直接拼法': 1,
#          '看單詞就能正確發音': 1,
#          '而英語拼寫是屬於間接拼法': 1,
#          '要藉助音標才知道單詞的正確發音': 1,
#          '英語中有一些單詞需要標記各種標音符號來提示發音': 1,
#          '這些單詞絕大部分都是從外語輸入進來': 1,
#          '標音符號在詩歌或劇本中有時也會用到': 1,
#          '能夠將平常不發音的音節標記爲發音': 1,
#          '來達到戲劇化的效果或者保持詩歌的韻律': 1,
#          '在古代或仿古作品中很常見': 1,
#          '的後綴經常標記開音符': 1,
#          '使其發音': 1,
#          '例': 1,
#          '在某些古文中': 1,
#          '特別是英式英語': 1,
#          '連字現象很普遍': 1,
#          '這些詞都爲拉丁或希臘詞源': 1,
#          '隨著時間推移和': 1,
#          '的盛行': 1,
#          '越來越少的英語使用者選擇標記': 1,
#          '或已經忘記這些詞是法語詞源': 1,
#          '即使在極爲正式的書寫當中也不加': 1,
#          '甚至有時候標記符號還會被認爲是在裝腔作勢': 1,
#          '但有人反對這種觀點': 1,
#          '認爲正確的拼寫應該保留符號': 1,
#          '尤其是缺少符號後發音就會出現很大差異時更應該如此': 1,
#          '有一些詞明顯不遵循英語的形態音位法': 1,
#          '在這類詞中一般會保留標音符號': 1,
#          '比如': 17,
#          '這個詞': 2,
#          '如果把': 1,
#          '上的閉音符去掉': 1,
#          '按照英語發音規則': 1,
#          '就會不發音': 1,
#          '又比如': 1,
#          '是摘要的意思': 1,
#          '有': 28,
#          '個音節': 2,
#          '是繼續的意思': 1,
#          '它們在英語詞典中始終分開兩條排列': 1,
#          '有時也需要用到分音符號': 1,
#          '但這些符號也經常省略或用連': 1,
#          '字': 7,
#          '符號代替': 1,
#          '或': 47,
#          '有一些單詞如': 1,
#          '最初傳到英語中時是要加標音符號的': 1,
#          '最開始時這些詞法國風情很濃': 1,
#          '一些人甚至批評': 1,
#          '本來英語中有對等的單詞卻偏要使用外國字彙': 1,
#          '還有一些詞如': 1,
#          '精英': 1,
#          '的標音符號在日常生活中已經消失': 1,
#          '但': 12,
#          '時代週刊': 1,
#          '等報刊雜誌仍然在使用': 1,
#          '孫臏': 2,
#          '孫臏孫臏': 1,
#          '公元前': 26,
#          '活躍於戰國中期軍事家': 1,
#          '兵家代表人物': 2,
#          '孫臏原名孫伯靈': 1,
#          '因受過臏刑故稱孫臏': 1,
#          '孫臏出生於阿': 1,
#          '鄄之間': 1,
#          '今山東省陽穀縣阿城鎮': 1,
#          '菏澤市鄄城縣北一帶': 1,
#          '是孫武的後代': 1,
#          '孫臏曾與龐涓爲同窗': 2,
#          '因受龐涓迫害遭受臏刑': 1,
#          '身體殘疾': 2,
#          '後在齊國使者的幫助下投奔齊國': 1,
#          '被齊威王任命爲軍師': 1,
#          '輔佐齊國大將田忌兩次擊敗龐涓': 1,
#          '取得桂陵之戰和馬陵之戰的勝利': 1,
#          '奠定齊國的霸業': 1,
#          '明末清初有以孫臏': 1,
#          '龐涓生平爲原型的歷史小說': 1,
#          '孫龐鬥志演義': 2,
#          '使孫龐鬥智的故事廣爲流傳': 1,
#          '唐德宗時將孫臏等歷史上六十四位武功卓著的名將供奉於武成王廟內': 1,
#          '被稱爲武成王廟六十四將': 1,
#          '宋徽宗時追尊孫臏爲武清伯': 1,
#          '位列宋武廟七十二將之一': 2,
#          '有人說孫臏是春秋時期吳國將軍孫武的後代': 1,
#          '而孫武活躍於前': 1,
#          '世紀末至前': 1,
#          '孫臏活躍於前': 1,
#          '兩人活躍年代相差': 1,
#          '多年': 5,
#          '孫臏的先祖是陳國公子陳完': 1,
#          '陳完的曾孫陳無宇有子陳書': 1,
#          '因討伐莒國有功': 1,
#          '被齊景公賜姓孫': 1,
#          '改名孫書': 1,
#          '封於樂安作爲食邑': 1,
#          '是嬀姓孫氏的始祖': 1,
#          '孫書之子孫憑生孫武': 1,
#          '孫武因躲避齊國國內發生的陳': 1,
#          '鮑': 1,
#          '高': 4,
#          '國四族之亂而出奔吳國': 1,
#          '有子三人': 1,
#          '孫馳': 1,
#          '孫明和孫敵': 1,
#          '次子孫明有子孫順': 1,
#          '孫順有子孫機': 1,
#          '孫機有子孫操': 1,
#          '孫操即爲孫臏之父': 1,
#          '即孫武': 1,
#          '孫明': 1,
#          '孫順': 1,
#          '孫機': 1,
#          '孫操': 1,
#          '此世系與二人相距年代基本吻合': 1,
#          '但唐代孫壬林自述家族世系的碑文卻記載孫臏是衛武公的後代': 1,
#          '二人一同拜師學習兵法': 1,
#          '龐涓後來出仕魏國': 1,
#          '擔任了魏惠王的將軍': 1,
#          '但是他認爲自己的才能比不上孫臏': 1,
#          '於是暗地派人將孫臏請到魏國加以監視': 1,
#          '孫臏到魏國後': 1,
#          '龐涓嫉妒他的才能': 1,
#          '於是捏造罪名將孫臏處以臏刑和黥刑': 1,
#          '砍去了孫臏的雙足並在他臉上刺字': 1,
#          '想使他埋沒於世不爲人知': 1,
#          '當齊國使者出使至魏國首都大梁': 1,
#          '今河南省開封市': 1,
#          '時': 20,
#          '孫臏以刑徒的身份祕密拜見齊國使者': 1,
#          '用言辭打動了他': 1,
#          '齊國使者覺得孫臏不同凡響': 1,
#          '於是偷偷地用車將他載回齊國': 1,
#          '逃奔到齊國的孫臏得到了田忌的賞識': 1,
#          '於是他寄居於田忌門下擔任門客': 1,
#          '田忌經常與齊國諸公子賽馬': 1,
#          '設重金作爲賭注': 1,
#          '孫臏發現比賽的馬腳力都差不多': 1,
#          '可分爲上': 1,
#          '中': 67,
#          '下三等': 1,
#          '於是建議田忌加大賭注': 1,
#          '並且向他保證必能取勝': 1,
#          '田忌於是與齊威王和諸公子設千金作爲賭注': 1,
#          '比試賽馬': 1,
#          '孫臏讓田忌用下等馬替換上等馬': 1,
#          '與齊威王的上等馬比賽': 1,
#          '首場大敗': 1,
#          '隨後孫臏又讓田忌用上等馬替換中等馬': 1,
#          '中等馬替換下等馬': 1,
#          '分別與齊威王的中等馬及下等馬比賽': 1,
#          '結果田忌兩勝一負': 1,
#          '最終贏得齊威王的千金賭注': 1,
#          '孫臏由此名聲大振': 1,
#          '田忌將孫臏推薦給齊威王': 1,
#          '齊威王向他請教兵法並讓他擔任自己的兵法教師': 1,
#          '前': 44,
#          '趙國進攻魏國的盟國衛國': 1,
#          '奪取了漆及富丘兩地': 1,
#          '均在今河南省長垣縣': 1,
#          '此舉招致了魏國的干涉': 1,
#          '魏國派兵包圍趙國首都邯鄲': 1,
#          '今河北省邯鄲市': 1,
#          '次年': 5,
#          '趙國派使者向齊': 1,
#          '楚兩國求救': 1,
#          '齊威王召集大臣們商議': 1,
#          '鄒忌反對救援': 1,
#          '而段幹朋則建議齊威王分兵一路向南攻打襄陵': 1,
#          '今河南省睢縣': 1,
#          '來疲勞魏軍': 1,
#          '然後趁魏軍攻破邯鄲後救援趙國': 1,
#          '這樣既救援了趙國': 1,
#          '又同時削弱了魏': 1,
#          '趙兩國': 1,
#          '齊威王採納段幹朋的建議': 1,
#          '兵分兩路': 1,
#          '一路齊軍圍攻魏國的襄陵': 1,
#          '一路由田忌': 2,
#          '孫臏率領救援趙國': 2,
#          '齊軍兵分兩路': 1,
#          '一路與宋國景': 1,
#          '衛國公孫倉所率部隊會合': 1,
#          '圍攻魏國的襄陵': 1,
#          '齊威王打算讓孫臏擔任主將': 1,
#          '但孫臏以遭受過酷刑': 1,
#          '身體有殘疾爲由拒絕': 1,
#          '齊威王於是任命田忌爲主將': 1,
#          '孫臏爲軍師': 2,
#          '讓坐在帶着蓬帳的車子中出謀劃策': 1,
#          '此時魏軍主力已攻破趙國首都邯鄲': 1,
#          '龐涓率軍': 1,
#          '萬到達茬丘': 1,
#          '今山東省茌平縣西': 1,
#          '隨後進攻衛國': 1,
#          '齊國方面田忌': 1,
#          '孫臏率軍八萬到達齊': 1,
#          '魏兩國邊境地區': 1,
#          '田忌想要直接與魏軍主力交戰': 1,
#          '但被孫臏阻止': 1,
#          '孫臏認爲魏國長期攻打趙國': 1,
#          '主力消耗於外': 1,
#          '老弱疲憊於內': 1,
#          '國內防務空虛': 1,
#          '應當採用聲東擊西': 1,
#          '圍魏救趙的戰術': 1,
#          '直搗魏國首都大梁迫使魏國撤軍': 1,
#          '魏國一撤軍': 1,
#          '趙國自然得救': 1,
#          '孫臏於是建議田忌南下佯攻魏國的平陵': 1,
#          '今山東省陽穀縣張秋鎮一帶': 1,
#          '因爲平陵城池雖小': 1,
#          '但管轄的地區很大': 1,
#          '人口衆多': 1,
#          '兵力很強': 1,
#          '是東陽地區': 1,
#          '指魏國首都大梁以東的地區': 1,
#          '的戰略要地': 1,
#          '很難被攻克': 1,
#          '而且平陵南面是宋國': 1,
#          '北面是衛國': 1,
#          '進軍途中要經過市丘': 1,
#          '容易被切斷糧道': 1,
#          '佯攻此地能很好的迷惑魏軍': 1,
#          '造成龐涓產生齊軍主將指揮無能的錯覺': 1,
#          '田忌採納孫臏的計謀': 1,
#          '拔營向平陵進軍': 1,
#          '接近平陵時': 1,
#          '孫臏向田忌建議由臨淄': 1,
#          '今山東省淄博市': 1,
#          '高唐': 1,
#          '今山東省高唐縣': 1,
#          '兩城的都大夫率軍直接向平陵發動攻擊': 1,
#          '吸引魏軍主力': 1,
#          '果然攻打平陵的兩路齊軍大敗': 1,
#          '孫臏讓田忌一面派出輕裝戰車': 1,
#          '直搗魏國首都大梁的城郊': 1,
#          '激怒龐涓迫使其率軍回援': 1,
#          '一面讓田忌派出少數部隊佯裝與龐涓的部隊交戰': 1,
#          '故作示弱使其輕敵': 1,
#          '田忌按孫臏的要求一一照辦': 1,
#          '龐涓果然丟掉輜重': 1,
#          '以輕裝急行軍晝夜兼程回救大梁': 1,
#          '孫臏帶領主力部隊在桂陵': 1,
#          '今河南省長垣縣西南': 1,
#          '設伏': 1,
#          '一舉擒獲龐涓': 1,
#          '桂陵之戰並沒有擊潰魏軍主力': 1,
#          '齊國也沒有正式進攻魏國首都大梁': 1,
#          '趙國首都邯鄲仍爲魏國所佔領': 1,
#          '魏惠王調用韓國的軍隊擊敗包圍襄陵的齊': 1,
#          '宋': 2,
#          '衛聯軍': 1,
#          '齊國被迫請楚國大將景捨出面調停': 1,
#          '各國休戰': 1,
#          '魏惠王與趙成侯在漳河邊結盟': 1,
#          '撤出趙國首都邯鄲': 1,
#          '大約在此時齊國將龐涓釋放': 1,
#          '使其回魏再度爲將': 1,
#          '魏將穰疵在南梁': 1,
#          '今河南省汝州市西': 1,
#          '和霍': 1,
#          '今河南省汝州市西南': 1,
#          '擊退韓將孔夜的軍隊': 1,
#          '韓昭侯派使者向齊國求救': 1,
#          '齊威王向大臣們詢問應當及早救韓還是推遲救韓': 1,
#          '張丏認爲如果晚救韓': 1,
#          '韓國必將轉而投靠魏國': 1,
#          '不如早救韓': 1,
#          '田忌則認爲趁韓': 1,
#          '魏之兵還未疲憊就出兵': 1,
#          '等於代替韓軍遭受魏軍的攻擊': 1,
#          '反而會受制於韓': 1,
#          '不如晚救韓等待魏軍疲憊': 1,
#          '韓國危在旦夕一定會求救於齊國': 1,
#          '這樣可以名利雙收': 1,
#          '齊威王十分贊同田忌的觀點': 1,
#          '祕密與韓國使者達成協議': 1,
#          '但沒有立即派出援軍援助韓國': 1,
#          '而韓國自恃有齊國的援助': 1,
#          '與魏國作戰接連五次戰敗': 1,
#          '不得不求救於齊國': 1,
#          '齊威王於是派田忌': 1,
#          '田朌爲主將': 1,
#          '田嬰爲副將': 1,
#          '率軍援助韓國': 1,
#          '孫臏再次採用圍魏救趙的戰術': 1,
#          '率軍襲擊魏國首都大梁': 1,
#          '龐涓得知消息後急忙從韓國撤軍返回魏國': 1,
#          '但齊軍此時已向西進軍': 1,
#          '孫臏考慮到魏軍自恃其勇': 1,
#          '一定會輕視齊軍': 1,
#          '況且齊軍也有怯戰的名聲': 1,
#          '應採用誘敵深入的戰術': 1,
#          '引誘魏軍進入埋伏圈後加以殲滅': 1,
#          '孫臏命令進入魏國境內的齊軍第一天埋設十萬個做飯的竈': 1,
#          '第二天減爲五萬個': 1,
#          '第三天減爲三萬個': 1,
#          '龐涓行軍三天查看齊軍留下的竈後非常高興': 1,
#          '說': 10,
#          '我本來就知道齊軍怯懦': 1,
#          '進入魏國境內才三天': 1,
#          '齊國士兵就已經逃跑了一大半': 1,
#          '於是丟下步兵': 1,
#          '只帶領精銳騎兵日夜兼程追擊齊軍': 1,
#          '孫臏估算龐涓天黑能行進至馬陵': 1,
#          '馬陵道路狹窄': 1,
#          '兩旁又多是峻隘險阻': 1,
#          '孫臏於是命士兵砍去道旁大樹的樹皮': 1,
#          '露出白木': 1,
#          '在樹上寫上': 1,
#          '龐涓死於此樹之下': 1,
#          '然後命令一萬名弓弩手埋伏在馬陵道兩旁': 1,
#          '約定': 1,
#          '天黑能在此處看到有火光就萬箭齊發': 1,
#          '龐涓果然當晚趕到砍去樹皮的大樹下': 1,
#          '見到白木上寫着字': 1,
#          '於是點火查看': 1,
#          '字還沒讀完': 1,
#          '齊軍伏兵萬箭齊發': 1,
#          '魏軍大亂': 1,
#          '龐涓自知敗局已定': 1,
#          '於是拔劍自刎': 1,
#          '臨死前說道': 1,
#          '遂成豎子之名': 1,
#          '齊軍乘勝追擊': 1,
#          '殲滅魏軍': 1,
#          '萬人': 151,
#          '俘斬魏國主將太子申': 1,
#          '經此一戰魏國元氣大傷': 1,
#          '從此每況愈下': 1,
#          '而齊國則稱霸東方': 1,
#          '成侯鄒忌一向與田忌不和': 1,
#          '馬陵之戰後': 1,
#          '孫臏對田忌說': 1,
#          '將軍有意做一番大事嗎': 1,
#          '田忌不知所以': 1,
#          '孫臏說': 1,
#          '將軍最好不要解除武裝返回齊國': 1,
#          '而是讓那些疲憊老弱的士兵來把守住主地': 1,
#          '今山東省淄博市西南': 1,
#          '主地的道路狹窄': 1,
#          '車輛只能依次通行': 1,
#          '碰撞摩擦而過': 1,
#          '如果讓那些疲憊老弱的士兵把守住主地': 1,
#          '定能以一當十': 1,
#          '以十當百': 1,
#          '以百當千': 1,
#          '然後將軍背靠泰山': 1,
#          '左有濟水': 1,
#          '右有高唐': 1,
#          '輜重可直達高宛': 1,
#          '今山東省桓臺縣境內': 1,
#          '只需輕車戰馬就可以直衝齊國首都臨淄的雍門': 1,
#          '如此': 1,
#          '齊國的大權就可以由將軍掌握決定了': 1,
#          '那時候鄒忌必定出逃': 1,
#          '否則將軍有可能不能安全的返回齊國': 1,
#          '但田忌沒有聽從孫臏的勸告': 1,
#          '後來鄒忌派公孫閱令人攜帶重金招搖過市': 1,
#          '找人占卜': 1,
#          '自我介紹道': 1,
#          '我是田忌將軍的臣屬': 1,
#          '如今將軍三戰三勝': 1,
#          '名震天下': 1,
#          '現在欲圖大事': 1,
#          '麻煩你占卜一下': 1,
#          '看看吉凶如何': 1,
#          '卜卦的人剛走': 1,
#          '公孫閱就派人逮捕占卜的人': 1,
#          '在齊威王面前驗證這番話': 1,
#          '田忌聞訊後大爲恐慌': 1,
#          '被迫出奔至楚國': 1,
#          '後被楚宣王封於江南': 1,
#          '今長江以南的地區': 1,
#          '孫臏這時也隨田忌來到楚國': 1,
#          '有可能一起去了田忌在江南的封地': 1,
#          '與弟子潛心著述': 1,
#          '孫臏兵法': 10,
#          '的大部分篇章': 1,
#          '可能是在楚國完成的': 1,
#          '齊宣王繼位後得知田忌被陷害': 1,
#          '將田忌召回國內官復原職': 1,
#          '而孫臏也於此時返回齊國': 1,
#          '太平御覽': 2,
#          '記載孫臏曾爲齊宣王獻上收服燕': 1,
#          '趙兩國來對抗秦國的計策': 1,
#          '後孫臏返回故地樂安頤養天年': 1,
#          '而班固的': 1,
#          '漢書': 13,
#          '和曾鞏的': 1,
#          '戰國策序': 1,
#          '卻記載孫臏不得善終': 1,
#          '孫臏有子孫勝': 1,
#          '字國輔': 1,
#          '擔任秦國將領': 1,
#          '據記載': 1,
#          '三國時期的東吳孫氏家族就是孫武': 1,
#          '孫臏的後代': 1,
#          '又稱': 4,
#          '齊孫子': 2,
#          '藝文志': 8,
#          '兵家權謀論著中記載孫臏著有': 1,
#          '八十九篇': 1,
#          '圖四卷': 1,
#          '自': 20,
#          '隋書': 4,
#          '經籍志': 3,
#          '便不見於歷代正史文獻著錄': 1,
#          '失傳近': 1,
#          '造成歷史上諸多對孫武': 1,
#          '孫臏其人及其著作的質疑': 1,
#          '在山東省臨沂市銀雀山漢墓同時出土了竹簡本的': 1,
#          '孫子兵法': 26,
#          '改變了學術界的認識': 1,
#          '現存的': 2,
#          '由出土的竹簡整理而成': 1,
#          '分上下兩編共三十一篇': 1,
#          '學術界認爲上編是在孫臏著作和言論的基礎上由其弟子輯錄': 1,
#          '整理而成': 1,
#          '下編在內容上雖與上編類似': 1,
#          '但在編撰體例上存在不同': 1,
#          '是否爲孫臏及其弟子所著尚無充分的證據': 1,
#          '以下爲': 1,
#          '的篇目及主要內容': 1,
#          '孫臏的軍事思想主要集中於': 1,
#          '明顯地接受了先祖孫武軍事思想的影響': 1,
#          '在軍隊建設方面': 1,
#          '孫臏主張': 2,
#          '注重將帥的選拔和培養': 1,
#          '將帥必須具有義': 1,
#          '仁': 1,
#          '德': 6,
#          '信': 3,
#          '智': 1,
#          '忠': 1,
#          '敢': 1,
#          '勇等素質': 1,
#          '此外還要': 1,
#          '知道': 1,
#          '懂得有關天': 1,
#          '地': 1,
#          '民': 1,
#          '敵': 1,
#          '陣各方面的作戰規律': 1,
#          '數戰': 1,
#          '長期的作戰經驗': 1,
#          '爲此': 4,
#          '他提出了二十種致使將帥作戰失敗的缺點和三十二種致使將帥作戰失敗的情況': 1,
#          '軍隊的編制方面': 1,
#          '孫臏主張要以地方行政組織爲單位': 1,
#          '以鄉里之長作爲軍中長官': 1,
#          '軍隊編制時要精簡精良': 1,
#          '不能濫竽充數': 1,
#          '君主': 1,
#          '將帥與兵': 1,
#          '民之間的關係方面': 1,
#          '孫臏主張君主要充分發揮將帥的軍事才能': 1,
#          '不要橫加干預': 1,
#          '將帥要取得君主的充分信任': 1,
#          '以便不受約束地指揮軍隊': 1,
#          '將官要對士兵': 1,
#          '視如赤子': 1,
#          '愛之若狡童': 1,
#          '敬之若嚴師': 1,
#          '將官要照顧士兵的利益': 1,
#          '關心他們的疾苦': 1,
#          '不能一味責罰': 1,
#          '要合理運用物質和精神雙重獎勵': 1,
#          '提高士兵作戰的積極性': 1,
#          '只有獲得百姓的擁護和支持': 1,
#          '軍隊才能具備強大的戰鬥力': 1,
#          '在法制與紀律方面': 1,
#          '孫臏主張軍隊必須有嚴格的法制和紀律約束': 1,
#          '將帥要賞罰分明': 1,
#          '一視同仁': 1,
#          '將帥如果明於道義': 1,
#          '信於賞罰': 1,
#          '會在軍隊中形成良好的道德風尚': 1,
#          '士兵就會自覺地遵守紀律': 1,
#          '在戰略原則上': 1,
#          '戰爭之前要多作準備': 1,
#          '要對戰爭結果進行謀算': 1,
#          '將帥在指揮作戰時': 1,
#          '必須根據戰場形勢': 1,
#          '大膽果斷地執行戰略戰術': 1,
#          '主張': 1,
#          '必攻不守': 1,
#          '積極進攻敵人沒有守備或守備薄弱的地方': 1,
#          '攻勢要猛烈': 1,
#          '窮追猛打': 1,
#          '積極奪取敵人的物資和戰略要地': 1,
#          '運用攻心爲上的策略': 1,
#          '合理運用政治和外交手段配合軍事行動': 1,
#          '鼓舞士氣方面': 1,
#          '孫臏提出分爲激氣': 1,
#          '利氣': 1,
#          '勵氣': 1,
#          '斷氣和延氣五個步驟': 1,
#          '戰術要機動靈活多變': 1,
#          '作戰要創造有利態勢': 1,
#          '在戰術方法上': 1,
#          '孫臏主張採用詭詐戰術誘敵上鉤': 1,
#          '集中兵力以多擊寡': 1,
#          '精選銳卒進行突破': 1,
#          '在運動戰中殲敵': 1,
#          '作戰時合理運用地形': 1,
#          '陣法': 1,
#          '發揮長兵和弓弩的威力': 1,
#          '此外': 56,
#          '孫臏還專門論述了攻城戰的策略和戰術': 1,
#          '但是孫臏的軍事思想也有其階級和時代的侷限性': 1,
#          '他對戰爭的性質分辨不清': 1,
#          '把士兵純粹當作被驅使的工具': 1,
#          '有些戰略戰術的表述過於簡單片面': 1,
#          '有時還夾雜着迷信觀念': 1,
#          '這也是應當指出的': 1,
#          '孫臏拳是清末民初在聊城': 1,
#          '館陶': 2,
#          '青島一帶流傳的一種外家拳術': 1,
#          '由於習練者穿長袖過指的衣服': 1,
#          '又被稱爲': 1,
#          '長袖拳': 1,
#          '但孫臏拳是否爲孫臏所創所傳': 1,
#          '已無從考證': 1,
#          '加上': 3,
#          '戰國策': 1,
#          '史記': 14,
#          '等史書亦不見有孫臏拳之記載': 1,
#          '另外孫臏拳在清末民初纔在聊城': 1,
#          '青島一帶流傳': 1,
#          '因此孫臏拳爲後人借用孫臏之名創出拳術的可能性亦不能排除': 1,
#          '孫臏拳已在中國大陸廣爲流傳': 1,
#          '於': 51,
#          '年孫臏拳被列爲第三批中國國家級非物質文化遺產': 1,
#          '孫臏作爲一名優秀的軍事家': 1,
#          '兩次擊敗魏國幫助齊國成就霸業': 1,
#          '並且著有': 1,
#          '一書': 4,
#          '爲後世留下重要軍事理論': 1,
#          '歷朝歷代對於孫臏都有很高的評價': 1,
#          '魯仲連稱讚孫臏': 1,
#          '食人炊骨': 1,
#          '士無反北之心': 1,
#          '是孫臏': 1,
#          '吳起之兵也': 1,
#          '班固稱讚孫臏': 1,
#          '當時吳有孫武': 1,
#          '齊有孫臏': 1,
#          '魏有吳起': 1,
#          '秦有商鞅': 1,
#          '皆擒敵立勝': 1,
#          '垂著篇籍': 1,
#          '葛洪評價孫臏': 1,
#          '孫臏思騁其祕略': 1,
#          '而司馬刖之': 1,
#          '幼學瓊林': 1,
#          '中稱讚孫臏': 1,
#          '孫臏吳起': 1,
#          '將略堪誇': 1,
#          '穰苴尉繚': 1,
#          '兵機莫測': 1,
#          '毛澤東對孫臏評價很高': 1,
#          '稱他': 1,
#          '攻魏救趙': 1,
#          '因敗魏軍': 1,
#          '千古高手': 1,
#          '孫臏遭到龐涓陷害失去雙足': 1,
#          '但他沒有自暴自棄': 1,
#          '最終兩次擊敗龐涓': 1,
#          '得以報仇': 1,
#          '孫臏身殘志堅的精神也得到了後世的稱讚': 1,
#          '司馬遷稱讚孫臏': 1,
#          '古者富貴而名磨滅': 1,
#          '不可勝記': 1,
#          '唯俶儻非常之人稱焉': 1,
#          '孫子臏腳': 1,
#          '兵法': 1,
#          '修列': 1,
#          '孔融評價孫臏': 1,
#          '不能止人遂爲非也': 1,
#          '適足絕人還爲善耳': 1,
#          '雖忠如鬻拳': 1,
#          '信如卞和': 1,
#          '智如孫臏': 1,
#          '冤如巷伯': 1,
#          '才如史遷': 1,
#          '達如子政': 1,
#          ...})

# %% [markdown]
# ## Ngram
#
# 一開始要先計算字詞出現的次數

# %%
# 熟悉Counter操作
from collections import Counter

c = Counter()
c['你好'] += 1    # 可以直接這樣做!
print(c)
print(Counter('你好') + Counter('hi'))
# Out:
# Counter({'你好': 1})
# Counter({'你': 1, '好': 1, 'h': 1, 'i': 1})

# %%
from collections import Counter

class Counters:
    def __init__(self, n):
        self.n = n
        self.counters = [Counter() for _ in range(n + 1)]  # 分別代表計算0、1、...個字的出現次數(這個沒解釋真的是看不懂, 代表看的n-1個字)

    def fit(self, segments: list):
        # 因為 self.counters 分別代表計算0、1、...個字的出現次數
        # 請在此實作利用 segments 以及函式 _skip 來統計次數(這邊是原敘述，寫得有點含糊，是說，要將每一句話都去計算Counter, 不用斷詞)
        # YOUR CODE HERE
        for i in range(1, self.n+1):    # 此時i代表看的字數
            for segment in segments:
                # 每一句都去算!Counter可以直接相加
                self.counters[i] += Counter(self._skip(segment, i))
        base_count = sum(dict(self.counters[1]).values())    # 總共有多少字, 為什麼要有這個!?
        self.counters[0] = Counter({'': base_count})
        # END YOUR CODE

    def __getitem__(self, k):
        """
            出現該
        """
        return self.counters[k]

    def _skip(self, segment, n):
        """
            這邊是return所有句子(segment)的看n周圍的word有哪些
        """
        assert n > 0
        if len(segment) < n:
            return []
        shift = n - 1
        for i in range(len(segment) - shift):
            yield segment[i:i+shift+1]

# %%
counters = Counters(n=3)
counters.fit(segments)

# %%
counters[0]
# 應該為： Counter({'': 371373})
# Out:
# Counter({'': 371373})

# %%
class Ngram:
    def __init__(self, n, counters):
        assert n <= counters.n
        self.n = n
        self.major_counter = counters[n]    # 只有n跟n-1是因為Ngram這個演算法是根據前n-1個字, 去看第n個字，故只需要(n-1)這個長度的聯合出現次數與n長度的聯合出現次數
        self.minor_counter = counters[n-1]

    def predict_proba(self, prefix='', top_k=5):
        """
            這是根據prefix去預測下一個字出現機率, 只是吃單一個輸入
        """
        assert len(prefix) >= self.n - 1
        # 使用 Ngram 的公式計算出下一個字出現的機率
        # 輸出為機率與字的tuple列表，詳見下方輸出範例
        # YOUR CODE HERE
        reference = prefix[-(self.n-1):] if self.n > 1 else ''    # 這個是真正的條件機率的條件部分
        count_reference = self.minor_counter[reference]         # 這是該prefix(真正的)的出現次數
        probs = []
        for key, count in self.major_counter.items():  # key:count==字:字的出現次數
            if key.startswith(reference):
                prob = count / count_reference
                probs.append((prob, key[-1]))    # -1代表最後, 也就是最新看到的字, 如: "我愛你", reference="我愛", key[-1]==我
        
        sorted_probs = sorted(probs, key=lambda x: x[0], reverse=True)
        # END YOUR CODE
        return sorted_probs[:top_k] if top_k > 0 else sorted_probs

    def get_proba_dict(self, prefix=''):
        return {word: prob for prob, word in self.predict_proba(prefix, top_k=-1)}

# %%
unigram = Ngram(1, counters)

# %%
unigram.predict_proba('我思')
# 應該為：[(0.035732269174118744, '的'),
#         (0.012927703414087723, '國'),
#         (0.010620050461395955, '中'),
#         (0.009984570768472667, '在'),
#         (0.009852627950874188, '一')]
# Out:
# [(0.035732269174118744, '的'),
#  (0.012927703414087723, '國'),
#  (0.010620050461395955, '中'),
#  (0.009984570768472667, '在'),
#  (0.009852627950874188, '一')]

# %%
bigram = Ngram(2, counters)
trigram = Ngram(3, counters)

# %% [markdown]
# ## 使用Ngram來建立第一版選字系統

# %%
class ChineseWordRecommenderV1:
    def __init__(self, unigram, bigram, trigram):
        self.unigram = unigram
        self.bigram = bigram
        self.trigram = trigram
    
    def predict_proba(self, prefix='', top_k=5):
        # 使用Ngram來建立選字系統
        # YOUR CODE HERE
        length = len(prefix)
        if length > 1:
            return self.trigram.predict_proba(prefix, top_k)
        elif length > 0:
            return self.bigram.predict_proba(prefix, top_k)
        else:
            return self.unigram.predict_proba(prefix, top_k)
        
        # END YOUR CODE

# %%
model = ChineseWordRecommenderV1(unigram, bigram, trigram)

# %%
probs = model.predict_proba('我思', top_k=10)
probs
# Out:
# [(0.75, '故'), (0.25, '維')]

# %% [markdown]
# ## Demo

# %%
# !pip install -U pip
# !pip install -q ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\users\aband\appdata\roaming\python\python37\site-packages (21.0)
# Collecting pip
#   Downloading pip-21.0.1-py3-none-any.whl (1.5 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.0
#     Uninstalling pip-21.0:
#       Successfully uninstalled pip-21.0
# Successfully installed pip-21.0.1
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
import ipywidgets as widgets

text = widgets.Textarea()
label = widgets.Label()
display(label, text)

def func(change):
    probs = model.predict_proba(change.new, top_k=10)
    label.value = ' ' + '\t'.join([word for prob, word in probs])

text.observe(func, names='value')
# Out:
# Label(value='')
# Textarea(value='')
